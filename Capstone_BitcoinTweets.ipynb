# %% [markdown]
# ## Capstone Project - Effect of Twitter Tweets on Bitcoin stock
#
# # Members: Uzi Gaeta, Abdullah Kobaissi, Michael Truong

# %% [markdown]
# First, we will do a map reduce and see the word frequency of each tweet that is exactly 1 day before the date of the bitcoin stock values. The goal is to have a brief examination of the words that can possibly affect the stock price for the next day.

# %%
# %%file tweets.py
from mrjob.job import MRJob
from mrjob.step import MRStep
from datetime import datetime, timedelta
import csv
import re
import emoji
import math            # for some stupid reason its the main csv file its floats instead of ints for followers
from collections import Counter
# import nltk
# from nltk.corpus import stopwords

class Tweet(MRJob):

    unique_tweets = set()
    viewingBTC_Price = False
    BTCPrices = dict()

    def steps(self):
        return [
            MRStep(mapper=self.mapper,
                reducer=self.shuffler),
            MRStep(reducer=self.reducer)
        ]
    
    def mapper(self, _, line):
        stop_words = [
            'the', 'and', 'a', 'of', 'in', 'to', 'that', 'it', 'with', 'for', 'on', 'is', 'can', 'below', 'him', 'some', 'against', 'the', 'did', "she's", 'which', 'but', 'yourself', 'if', 'y', 'what', "you've", 'is', 'myself', 'ours', 'further', 'out', 'own', 'most', "isn't", 'its', 'we', "haven't", 'mustn', 'by', "don't", 'didn', 'should', 'there', 'of', 'were', 'won', 'how', 'more', 'as', 'any', 'very', "couldn't", 'hasn', 'needn', 'now', 'ain', 'again', 'so', 'where', 'them', 'your', 'before', 'why', 'after', 'under', "should've", "won't", 'their', 'than', 'and', "that'll", 'whom', 'because', 'are', "aren't", 'on', 'weren', 'yours', 'doesn', "mustn't", 'nor', "hadn't", 'am', 'couldn', 'during', 'same', 'yourselves', 'mightn', 'was', 'up', 'ma', 've', "didn't", 'over', 're', 'once', "mightn't", 'who', 'these', 'those', 'he', 'only', 'm', 'being', 'wasn', 'shouldn', 'it', 'do', 'have', 'doing', 'my', "shouldn't", 'above', "hasn't", 'ourselves', 'no', 'both', 'a', 'such', 'between', 'not', "wouldn't", 'off', "you're", "you'll", 'then', 'd', 'o', 'does', 'or', 'hers', 'our', "wasn't", 'hadn', 'other', 'aren', 'will', 'about', 'don', 'shan', "it's", 'just', 'too', 'while', 'his', 'in', 'through', 'themselves', 'that', 'having', 'until', 'at', 'few', 'theirs', 'each', "needn't", 'for', 'you', 'herself', 'itself', 'she', 'has', 't', 'to', 'haven', 'this', 'here', 'with', 'himself', 'an', 's', 'isn', 'had', "you'd", 'into', 'they', 'll', 'her', 'when', 'wouldn', 'from', "weren't", 'all', "doesn't", "shan't", 'down', 'been', 'be', 'me', 'i','\\' 
        ]
        stop_words = set(stop_words)
        fields = line.strip().split(',')
        if line == ("2016-01-01,430.721008,436.246002,427.515015,434.334015,434.334015,36278900"):  #start of BTC-USD.csv
            Tweet.viewingBTC_Price = True
            return
        if Tweet.viewingBTC_Price:
            BTCDate, openPrice, high, low, closePrice, adjClose, volume = fields[0], fields[1], fields[2], fields[3], fields[4], fields[5], fields[6]
            #yield BTCDate, {"openPrice": openPrice, "closePrice": closePrice} 
            Tweet.BTCPrices[BTCDate] = {"openPrice": openPrice, "closePrice": closePrice, "high": high, "low": low, "volume": volume} 
            #yield BTCDate, Tweet.BTCPrices


        elif len(fields) >= 13: # viewing bitcoin_tweets.csv;   need to make sure there are 13 columns in a line
            # Extract the desired fields
            if fields[0]== '':
                return
            user_name = fields[0]
            user_location = fields[1]
            user_description = fields[2]
            #yield "test", {"idk": fields[8], "idk2": fields[3]}
            try:
                #datetime.strptime(fields[3], '%Y-%m-%d %H:%M:%S')                #check
                dt_obj = datetime.strptime(fields[3], '%Y-%m-%d %H:%M:%S')
                date_str = dt_obj.strftime('%Y-%m-%d')
                user_created = date_str
            except ValueError:
                return               #discard lines that dont have date       
            try:
                user_followers = float(fields[4])
            except ValueError:     
                return           #discard lines that dont have proper type      
            try:
                user_friends = math.floor(float(fields[5]))
            except ValueError:
                return
            try:
                user_favourites = int(fields[6])  # thats how they spelled favorites in the csv
            except ValueError:
                user_favourites = None
                # return
            try:
                user_verified = bool(fields[7])  
            except ValueError:
                user_verified = None
                # return
            try:
                dt_obj = datetime.strptime(fields[8], '%Y-%m-%d %H:%M:%S')
                date_str = dt_obj.strftime('%Y-%m-%d')
                date = date_str
            except:
                return 
            PUNC_RE = re.compile(r"[^a-z]")
            text = re.sub(PUNC_RE, ' ', fields[9].lower())
            text = re.sub(r'[^\x00-\x7F]+', '', text)
            # Remove URLs
            text = re.sub(r'http\S+', '', text)
            # Convert to lowercase
            text = text.lower()
            # remove mentions
            text = re.sub(r'@\w+',' ', text)
            # remove utf-16 stuff
            text = re.sub(r'\\u\w{4}', '', text)
            # Remove stop words
            words = text.split()
            words = [word for word in words if word not in stop_words]
            cleaned_text = ' '.join(words)
            text = cleaned_text

            hashtags = re.findall(r'#\w+', text)  # get hashtags in description
            source = fields[11]
            try:
                is_retweet = bool(fields[12])  # thats how they spelled favorites in the csv lol
            except ValueError:
                return
            
            # Check if tweet is a duplicate
            tweet_key = (user_name, cleaned_text)
            if tweet_key in Tweet.unique_tweets:
                # yield user_name, {                 # there are a lot of duplicate tweets
                # "user_location": user_location,
                # "user_description": user_description,
                # "user_created": user_created,
                # "user_followers": user_followers,
                # "user_friends": user_friends,
                # "user_favourites": user_favourites,
                # "user_verified": user_verified,
                # "date": date,
                # "text": text,
                # "hashtags": hashtags,
                # "source": source,
                # "is_retweet": is_retweet
                # }
                return

            Tweet.unique_tweets.add(tweet_key)
            yield date, {
                "user_name": user_name,
                "user_location": user_location,
                "user_description": user_description,
                "user_created": user_created,
                "user_followers": user_followers,
                "user_friends": user_friends,
                "user_favourites": user_favourites,
                "user_verified": user_verified,
                "text": text,
                "hashtags": hashtags,
                "source": source,
                "is_retweet": is_retweet
            }
            #yield user_name, text

    def shuffler(self, key, values):
        # make the BTCDate the key and make the 
        #tweets = 

        # for tweet in values:
        #     yield key, tweet

        #yield key, Tweet.BTCPrices
        if key not in Tweet.BTCPrices:
            return
        
        date_obj = datetime.strptime(key, "%Y-%m-%d").date()
        next_day = date_obj + timedelta(days=1)   #date obj
        next_day = next_day.strftime("%Y-%m-%d") #string

        openPrice = Tweet.BTCPrices[next_day]['openPrice']
        closePrice = Tweet.BTCPrices[next_day]['closePrice']
        high = Tweet.BTCPrices[next_day]['high']
        low = Tweet.BTCPrices[next_day]['low']
        volume = Tweet.BTCPrices[next_day]['volume']
        for tweet in values:
            user_name = tweet['user_name']
            user_location = tweet['user_location']
            user_description = tweet['user_description']
            user_created = tweet['user_created']
            user_followers = tweet['user_followers']
            user_friends = tweet['user_friends']
            user_favourites = tweet['user_favourites']
            user_verified = tweet['user_verified']
            text = tweet['text']
            hashtags = tweet['hashtags']
            source = tweet['source']
            is_retweet = tweet['is_retweet']
            yield key, {
                "user_name": user_name,
                "text": text,
                "hashtags": hashtags,
                "openPrice": openPrice,
                "closePrice": closePrice,
                "high": high,
                "low": low,
                "volume": volume
            }
            #yield key, tweet
    
    def reducer(self, key, values):
        # # Combine all the tweets from a user into a single list
        # tweets = list(values)
        
        # # Yield the user and their list of tweets
        # yield user_name, tweets

        # tweet_count = sum(1 for _ in values)
        # yield key, tweet_count
        # date_obj = datetime.strptime(key, "%Y-%m-%d").date()
        # next_day = date_obj + timedelta(days=1)   #date obj
        # next_day = next_day.strftime("%Y-%m-%d") #string
        store = Counter()
        # openPrice = float(Tweet.BTCPrices[next_day]['openPrice'])
        # closePrice = float(Tweet.BTCPrices[next_day]['closePrice'])
        for val in values:
            
            # extract the relevant fields from the tweet
            # user_location = tweet['user_location']
            # user_description = tweet['user_description']
            # user_created = tweet['user_created']
            # user_followers = tweet['user_followers']
            # user_friends = tweet['user_friends']
            # user_favourites = tweet['user_favourites']
            # user_verified = tweet['user_verified']
            # date = tweet['date']
            # text = tweet['text']
            # hashtags = tweet['hashtags']
            # source = tweet['source']
            # is_retweet = tweet['is_retweet']
            openPrice = float(val["openPrice"])     
            closePrice = float(val["closePrice"])
            high = float(val["high"])
            low = float(val["low"])
            volume = float(val["volume"])

            words = re.sub(r'#\w+', '', val["text"])  # rm hashtags in description
            words = words.split()
            #you can use logic here to say filter: ex-> only add tweet text to store if they have 1000 < followers
            store.update(words)
            

            

        word_count = sorted(store.items(), key=lambda x: x[1])#, reverse=True)   # sort dict
        # lower_bound = int(len(word_count) * 0.4)
        # upper_bound = int(len(word_count) * 0.6)
        # word_count = dict(sorted_word_count[lower_bound:upper_bound])
        word_count = dict(word_count)
        word_count = {k: v for k, v in word_count.items() if v >= 3}  # only include words with 3 or more count 

        high = format(high-openPrice, '.2f')
        low = format(low-openPrice, '.2f')
        volume = format(volume, '.2f')
        diff = format(closePrice-openPrice, '.2f')

        yield {"TweetDate": key, "OpenPrice - ClosePrice for next day": diff}, {"high": high, "low": low, "volume": volume, "word_count": word_count}

        #yield key, text
        # for tweet in values:
        #     yield key, "test"


if __name__ == '__main__':
    Tweet.run()
# Out:
# Overwriting tweets.py

# %%
# !python tweets.py Bitcoin_tweets_dataset_2.csv BTC-USD.csv
#!python tweets.py Bitcoin_tweets.csv BTC-USD.csv
# Out:
following":3,"different":3,"fair":3,"merchants":3,"within":3,"mine":3,"nice":3,"fee":3,"whalechart":3,"country":3,"russia":3,"scam":3,"major":3,"agreed":3,"followers":3,"powered":3,"talk":3,"trend":3,"bounce":3,"taxes":3,"ups":3,"downs":3,"folks":3,"ago":3,"push":3,"agree":3,"volatility":3,"sec":3,"create":3,"war":3,"scottmelker":3,"second":3,"amazing":3,"helps":3,"holding":3,"knowledge":3,"ercwl":3,"minting":3,"pigeon":3,"ui":3,"ustc":3,"dokwon":3,"index":3,"morning":3,"video":3,"exclusive":3,"facts":3,"maxis":3,"exchanges":3,"io":3,"agentorangebtc":3,"bro":3,"black":3,"americans":3,"stone":3,"prediction":3,"drop":3,"offer":3,"fully":3,"actually":3,"lead":3,"localbitcoins":3,"account":3,"likes":3,"dont":3,"cryptocom":3,"dscbland":3,"base":3,"nobody":3,"cryptos":3,"xmr":3,"hell":3,"fintech":3,"told":3,"loveisland":3,"oriele":3,"wake":3,"hits":3,"tuurdemeester":3,"benmagelsen":3,"policy":3,"safe":3,"portfolio":3,"communities":3,"anything":3,"cg":3,"shiba":3,"least":3,"ordinalswallet":3,"legendary":3,"trendline":3,"code":3,"cro":3,"ionx":3,"global":3,"hour":3,"predictable":3,"view":3,"undervalued":3,"moves":3,"field":3,"moving":3,"built":3,"information":3,"sales":3,"moment":3,"volatile":3,"pattern":3,"clear":3,"friends":3,"realflokiinu":3,"satoshiflipper":3,"sorry":3,"west":3,"cybersecurity":3,"becomes":3,"unordinals":3,"nation":3,"channel":3,"full":3,"legitimacy":3,"ease":3,"sees":3,"bitcoiners":3,"ordinalnfts":3,"pepe":3,"dia":3,"metamask":3,"interoperability":3,"america":4,"rank":4,"massive":4,"stopped":4,"trade":4,"hours":4,"lot":4,"loss":4,"sides":4,"conflict":4,"guess":4,"looks":4,"tether":4,"wowbitcoinrocks":4,"reality":4,"lives":4,"cointelegraph":4,"answer":4,"payouts":4,"hack":4,"hacking":4,"pm":4,"cryptocurrencymarket":4,"data":4,"open":4,"imo":4,"give":4,"dream":4,"opportunities":4,"sign":4,"fud":4,"due":4,"bearish":4,"bitcoinofficesv":4,"king":4,"despite":4,"bitcoins":4,"together":4,"halving":4,"self":4,"government":4,"tax":4,"said":4,"family":4,"luna":4,"nftc ...
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\micha\AppData\Local\Temp\tweets.micha.20230508.063429.662784
# Running step 1 of 2...
# Running step 2 of 2...
# job output is in C:\Users\micha\AppData\Local\Temp\tweets.micha.20230508.063429.662784\output
# Streaming final output from C:\Users\micha\AppData\Local\Temp\tweets.micha.20230508.063429.662784\output...
# Removing temp directory C:\Users\micha\AppData\Local\Temp\tweets.micha.20230508.063429.662784...

# %% [markdown]
# Then, we will get all the tweet dates with that word and get the average of the difference of the closePrice and openPrice. This will see if certain words in a tweet have a strong correlation to the stock dropping or rising for the next day.

# %%
# %%file tweets.py
from mrjob.job import MRJob
from mrjob.step import MRStep
from datetime import datetime, timedelta
import csv
import re
#import emoji
import math            # for some stupid reason its the main csv file its floats instead of ints for followers
from collections import Counter
# import nltk
# from nltk.corpus import stopwords

class Tweet(MRJob):

    unique_tweets = set()
    viewingBTC_Price = False
    BTCPrices = dict()

    def steps(self):
        return [
            MRStep(mapper=self.mapper,
                reducer=self.shuffler),
            MRStep(reducer=self.reducer),
            MRStep(mapper=self.mapper2,
                reducer=self.reducer2),
            #MRStep(mapper=self.mapper3)
             #    reducer=self.reducer2)
        ]
    
    def mapper(self, _, line):
        stop_words = [
            'the', 'and', 'a', 'of', 'in', 'to', 'that', 'it', 'with', 'for', 'on', 'is', 'can', 'below', 'him', 'some', 'against', 'the', 'did', "she's", 'which', 'but', 'yourself', 'if', 'y', 'what', "you've", 'is', 'myself', 'ours', 'further', 'out', 'own', 'most', "isn't", 'its', 'we', "haven't", 'mustn', 'by', "don't", 'didn', 'should', 'there', 'of', 'were', 'won', 'how', 'more', 'as', 'any', 'very', "couldn't", 'hasn', 'needn', 'now', 'ain', 'again', 'so', 'where', 'them', 'your', 'before', 'why', 'after', 'under', "should've", "won't", 'their', 'than', 'and', "that'll", 'whom', 'because', 'are', "aren't", 'on', 'weren', 'yours', 'doesn', "mustn't", 'nor', "hadn't", 'am', 'couldn', 'during', 'same', 'yourselves', 'mightn', 'was', 'up', 'ma', 've', "didn't", 'over', 're', 'once', "mightn't", 'who', 'these', 'those', 'he', 'only', 'm', 'being', 'wasn', 'shouldn', 'it', 'do', 'have', 'doing', 'my', "shouldn't", 'above', "hasn't", 'ourselves', 'no', 'both', 'a', 'such', 'between', 'not', "wouldn't", 'off', "you're", "you'll", 'then', 'd', 'o', 'does', 'or', 'hers', 'our', "wasn't", 'hadn', 'other', 'aren', 'will', 'about', 'don', 'shan', "it's", 'just', 'too', 'while', 'his', 'in', 'through', 'themselves', 'that', 'having', 'until', 'at', 'few', 'theirs', 'each', "needn't", 'for', 'you', 'herself', 'itself', 'she', 'has', 't', 'to', 'haven', 'this', 'here', 'with', 'himself', 'an', 's', 'isn', 'had', "you'd", 'into', 'they', 'll', 'her', 'when', 'wouldn', 'from', "weren't", 'all', "doesn't", "shan't", 'down', 'been', 'be', 'me', 'i','\\' 
        ]
        stop_words = set(stop_words)
        fields = line.strip().split(',')
        if line == ("2016-01-01,430.721008,436.246002,427.515015,434.334015,434.334015,36278900"):  #start of BTC-USD.csv
            Tweet.viewingBTC_Price = True
            return
        if Tweet.viewingBTC_Price:
            BTCDate, openPrice, high, low, closePrice, adjClose, volume = fields[0], fields[1], fields[2], fields[3], fields[4], fields[5], fields[6]
            #yield BTCDate, {"openPrice": openPrice, "closePrice": closePrice} 
            Tweet.BTCPrices[BTCDate] = {"openPrice": openPrice, "closePrice": closePrice, "high": high, "low": low, "volume": volume} 
            #yield BTCDate, Tweet.BTCPrices


        elif len(fields) >= 13: # viewing bitcoin_tweets.csv;   need to make sure there are 13 columns in a line
            # Extract the desired fields
            if fields[0]== '':
                return
            user_name = fields[0]
            user_location = fields[1]
            user_description = fields[2]
            #yield "test", {"idk": fields[8], "idk2": fields[3]}
            try:
                #datetime.strptime(fields[3], '%Y-%m-%d %H:%M:%S')                #check
                dt_obj = datetime.strptime(fields[3], '%Y-%m-%d %H:%M:%S')
                date_str = dt_obj.strftime('%Y-%m-%d')
                user_created = date_str
            except ValueError:
                return               #discard lines that dont have date       
            try:
                user_followers = float(fields[4])
            except ValueError:     
                return           #discard lines that dont have proper type      
            try:
                user_friends = math.floor(float(fields[5]))
            except ValueError:
                return
            try:
                user_favourites = int(fields[6])  # thats how they spelled favorites in the csv
            except ValueError:
                user_favourites = None
                # return
            try:
                user_verified = bool(fields[7])  
            except ValueError:
                user_verified = None
                # return
            try:
                dt_obj = datetime.strptime(fields[8], '%Y-%m-%d %H:%M:%S')
                date_str = dt_obj.strftime('%Y-%m-%d')
                date = date_str
            except:
                return 
            PUNC_RE = re.compile(r"[^a-z]")
            text = re.sub(PUNC_RE, ' ', fields[9].lower())
            text = re.sub(r'[^\x00-\x7F]+', '', text)
            # Remove URLs
            text = re.sub(r'http\S+', '', text)
            # Convert to lowercase
            text = text.lower()
            # remove mentions
            text = re.sub(r'@\w+',' ', text)
            # remove utf-16 stuff
            text = re.sub(r'\\u\w{4}', '', text)
            # Remove stop words
            words = text.split()
            words = [word for word in words if word not in stop_words]
            cleaned_text = ' '.join(words)
            text = cleaned_text

            hashtags = re.findall(r'#\w+', text)  # get hashtags in description
            source = fields[11]
            try:
                is_retweet = bool(fields[12])  # thats how they spelled favorites in the csv lol
            except ValueError:
                return
            
            # Check if tweet is a duplicate
            tweet_key = (user_name, cleaned_text)
            if tweet_key in Tweet.unique_tweets:
                # yield user_name, {                 # there are a lot of duplicate tweets
                # "user_location": user_location,
                # "user_description": user_description,
                # "user_created": user_created,
                # "user_followers": user_followers,
                # "user_friends": user_friends,
                # "user_favourites": user_favourites,
                # "user_verified": user_verified,
                # "date": date,
                # "text": text,
                # "hashtags": hashtags,
                # "source": source,
                # "is_retweet": is_retweet
                # }
                return

            Tweet.unique_tweets.add(tweet_key)
            yield date, {
                "user_name": user_name,
                "user_location": user_location,
                "user_description": user_description,
                "user_created": user_created,
                "user_followers": user_followers,
                "user_friends": user_friends,
                "user_favourites": user_favourites,
                "user_verified": user_verified,
                "text": text,
                "hashtags": hashtags,
                "source": source,
                "is_retweet": is_retweet
            }
            #yield user_name, text

    def shuffler(self, key, values):
        # make the BTCDate the key and make the 
        #tweets = 

        # for tweet in values:
        #     yield key, tweet

        #yield key, Tweet.BTCPrices
        if key not in Tweet.BTCPrices:
            return
        
        date_obj = datetime.strptime(key, "%Y-%m-%d").date()
        next_day = date_obj + timedelta(days=1)   #date obj
        next_day = next_day.strftime("%Y-%m-%d") #string

        openPrice = Tweet.BTCPrices[next_day]['openPrice']
        closePrice = Tweet.BTCPrices[next_day]['closePrice']
        high = Tweet.BTCPrices[next_day]['high']
        low = Tweet.BTCPrices[next_day]['low']
        volume = Tweet.BTCPrices[next_day]['volume']
        for tweet in values:
            user_name = tweet['user_name']
            user_location = tweet['user_location']
            user_description = tweet['user_description']
            user_created = tweet['user_created']
            user_followers = tweet['user_followers']
            user_friends = tweet['user_friends']
            user_favourites = tweet['user_favourites']
            user_verified = tweet['user_verified']
            text = tweet['text']
            hashtags = tweet['hashtags']
            source = tweet['source']
            is_retweet = tweet['is_retweet']
            yield key, {
                "user_name": user_name,
                "text": text,
                "hashtags": hashtags,
                "openPrice": openPrice,
                "closePrice": closePrice,
                "high": high,
                "low": low,
                "volume": volume
            }
            #yield key, tweet
    
    def reducer(self, key, values):
        # # Combine all the tweets from a user into a single list
        # tweets = list(values)
        
        # # Yield the user and their list of tweets
        # yield user_name, tweets

        # tweet_count = sum(1 for _ in values)
        # yield key, tweet_count
        # date_obj = datetime.strptime(key, "%Y-%m-%d").date()
        # next_day = date_obj + timedelta(days=1)   #date obj
        # next_day = next_day.strftime("%Y-%m-%d") #string
        store = Counter()
        # openPrice = float(Tweet.BTCPrices[next_day]['openPrice'])
        # closePrice = float(Tweet.BTCPrices[next_day]['closePrice'])
        for val in values:
            
            # extract the relevant fields from the tweet
            # user_location = tweet['user_location']
            # user_description = tweet['user_description']
            # user_created = tweet['user_created']
            # user_followers = tweet['user_followers']
            # user_friends = tweet['user_friends']
            # user_favourites = tweet['user_favourites']
            # user_verified = tweet['user_verified']
            # date = tweet['date']
            # text = tweet['text']
            # hashtags = tweet['hashtags']
            # source = tweet['source']
            # is_retweet = tweet['is_retweet']
            openPrice = float(val["openPrice"])     
            closePrice = float(val["closePrice"])
            high = float(val["high"])
            low = float(val["low"])
            volume = float(val["volume"])

            words = re.sub(r'#\w+', '', val["text"])  # rm hashtags in description
            words = words.split()
            #you can use logic here to say filter: ex-> only add tweet text to store if they have 1000 < followers
            store.update(words)
            

            

        word_count = sorted(store.items(), key=lambda x: x[1])#, reverse=True)   # sort dict
        # lower_bound = int(len(word_count) * 0.4)
        # upper_bound = int(len(word_count) * 0.6)
        # word_count = dict(sorted_word_count[lower_bound:upper_bound])
        word_count = dict(word_count)
        word_count = {k: v for k, v in word_count.items() if v >= 3}  # only include words with 3 or more count 

        high = format(high-openPrice, '.2f')
        low = format(low-openPrice, '.2f')
        volume = format(volume, '.2f')
        #diff = format(closePrice-openPrice, '.2f')

        yield key, {"open_close_diff_nextday": (closePrice-openPrice), "word_count": word_count, "high": high, "low": low, "volume": volume }

        #yield key, text
        # for tweet in values:
        #     yield key, "test"

    def mapper2(self, date, vals):

        #yield key, val
        open_close_diff_nextday = vals["open_close_diff_nextday"]
        high = vals["high"]
        low = vals["low"]
        volume = vals["volume"]
        word_counts = vals["word_count"]
        #yield date, word_counts
        for word, count in word_counts.items():
            yield word, {"open_close_diff_nextday": open_close_diff_nextday, "date": date, "word_count": word_counts[word], "high": high, "low": low, "volume": volume}
        #for word, count in word_counts.items():

    def reducer2(self, word, vals):
        #open_close_diff_nextday = vals["open_close_diff_nextday"]
        #date = vals["date"]
        #word_count = vals["word_count"]
        datesPerWord = 0
        totalWordCount = 0
        maxDiff = float('-inf')
        minDiff = float('inf')
        totalHigh = 0
        totalLow = 0
        totalVolume = 0
        open_close_DiffTotal = 0
        #yield word, {"wordInDate": 1, "date": date, "open_close_diff_nextday": open_close_diff_nextday, "word_count": word_count}
        for x in vals:
            datesPerWord += 1
            totalWordCount += x['word_count']
            open_close_DiffTotal += x["open_close_diff_nextday"]
            totalHigh += float(x["high"])
            totalLow += float(x["low"])
            totalVolume += float(x["volume"])
            maxDiff = max(x["open_close_diff_nextday"], maxDiff)
            minDiff = min(x["open_close_diff_nextday"], minDiff)
            

        maxDiff = format(maxDiff, '.2f')
        minDiff = format(minDiff, '.2f')
        averageDiff = format((open_close_DiffTotal / datesPerWord), '.2f')
        averageHigh = format((totalHigh / datesPerWord), '.2f')
        averageLow = format((totalLow / datesPerWord), '.2f')
        averageVolume = format((totalVolume / datesPerWord), '.2f')


        yield word, {"averageDiff": averageDiff, "maxDiff": maxDiff, "minDiff": minDiff, "averageHigh": averageHigh, "averageLow": averageLow, "averageVolume": averageVolume, "totalWordCount": totalWordCount}
        #yield word, {"datesPerWord": datesPerWord, "totalWordCount": totalWordCount, }
        #yield word, {"wordInDate": x, "date": date, "open_close_diff_nextday": open_close_diff_nextday, "word_count": word_count}

    # def reducer2(self, word, vals):
    #     datesPerWord = 0
    #     open_close_diff_total = 0
    #     #total_word
    #     maxRise = float('-inf')
    #     maxDrop = float('inf')
    #     for totals in vals:
    #         #word_count = vals["word_count"]
    #         maxRise = max(totals["open_close_diff_nextday"], maxRise)
    #         maxDrop = min(totals["open_close_diff_nextday"], maxDrop)
    #         datesPerWord += totals["wordInDate"]
    #         open_close_diff_total += totals["open_close_diff_nextday"]

    #     maxRise = format(maxRise, '.2f')
    #     maxDrop = format(maxDrop, '.2f')
    #     averageDiff = format((open_close_diff_total / datesPerWord), '.2f')

    #     yield word, {"AverageDiff": averageDiff, "maxRise": maxRise, "maxDrop": maxDrop}

if __name__ == '__main__':
    Tweet.run()
# Out:
# Overwriting tweets.py

# %%
# !python tweets.py Bitcoin_tweets_dataset_2.csv BTC-USD.csv
#!python tweets.py Bitcoin_tweets.csv BTC-USD.csv
# Out:
# "aa"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":3}
# "aag"	{"averageDiff":"-374.48","maxDiff":"-374.48","minDiff":"-374.48","averageHigh":"63.55","averageLow":"-444.19","averageVolume":"20535363434.00","totalWordCount":3}
# "aaron"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":5}
# "aave"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":4}
# "ability"	{"averageDiff":"-441.36","maxDiff":"-38.58","minDiff":"-1113.95","averageHigh":"130.42","averageLow":"-673.65","averageVolume":"23036522206.67","totalWordCount":12}
# "able"	{"averageDiff":"-125.69","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"254.67","averageLow":"-372.63","averageVolume":"20740433741.33","totalWordCount":39}
# "abruptly"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":4}
# "absolute"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":6}
# "absolutely"	{"averageDiff":"-149.42","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"276.10","averageLow":"-426.05","averageVolume":"21417881910.60","totalWordCount":34}
# "abstraction"	{"averageDiff":"-642.75","maxDiff":"-171.55","minDiff":"-1113.95","averageHigh":"47.41","averageLow":"-832.70","averageVolume":"23224401563.00","totalWordCount":10}
# "ac"	{"averageDiff":"228.52","maxDiff":"495.62","minDiff":"-38.58","averageHigh":"513.07","averageLow":"-208.94","averageVolume":"23661802347.00","totalWordCount":13}
# "academy"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":4}
# "accelerate"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":3}
# "accelerator"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "accept"	{"averageDiff":"-109.10","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"224.32","averageLow":"-342.81","averageVolume":"19372659337.29","totalWordCount":54}
# "accepted"	{"averageDiff":"-42.92","maxDiff":"81.37","minDiff":"-171.55","averageHigh":"216.03","averageLow":"-268.19","averageVolume":"18788054581.00","totalWordCount":10}
# "accepting"	{"averageDiff":"-178.99","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"330.65","averageLow":"-457.56","averageVolume":"21347415847.67","totalWordCount":13}
# "accepts"	{"averageDiff":"-166.62","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"267.78","averageLow":"-461.30","averageVolume":"21138005554.25","totalWordCount":14}
# "access"	{"averageDiff":"-265.88","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"101.28","averageLow":"-404.34","averageVolume":"18136729016.83","totalWordCount":37}
# "accessible"	{"averageDiff":"162.03","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"410.91","averageLow":"-232.15","averageVolume":"22524619858.00","totalWordCount":9}
# "according"	{"averageDiff":"-102.56","maxDiff":"81.37","minDiff":"-374.48","averageHigh":"150.78","averageLow":"-282.54","averageVolume":"17613108018.00","totalWordCount":20}
# "account"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":180}
# "accounting"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":4}
# "accounts"	{"averageDiff":"-250.46","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"138.61","averageLow":"-446.38","averageVolume":"18718516253.20","totalWordCount":33}
# "accumulate"	{"averageDiff":"-117.02","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"266.13","averageLow":"-378.44","averageVolume":"19573804790.00","totalWordCount":26}
# "accumulating"	{"averageDiff":"-154.89","maxDiff":"81.37","minDiff":"-374.48","averageHigh":"138.40","averageLow":"-297.73","averageVolume":"18079587894.33","totalWordCount":10}
# "accumulation"	{"averageDiff":"95.16","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"372.75","averageLow":"-273.29","averageVolume":"22570001070.00","totalWordCount":113}
# "accurate"	{"averageDiff":"-105.07","maxDiff":"-38.58","minDiff":"-171.55","averageHigh":"194.28","averageLow":"-378.78","averageVolume":"21523581005.00","totalWordCount":7}
# "achievement"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "achievements"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
# "acknowledgment"	{"averageDiff":"-7.06","maxDiff":"-7.06","minDiff":"-7.06","averageHigh":"147.48","averageLow":"-105.50","averageVolume":"17353192895.00","totalWordCount":4}
# "acquired"	{"averageDiff":"-374.48","maxDiff":"-374.48","minDiff":"-374.48","averageHigh":"63.55","averageLow":"-444.19","averageVolume":"20535363434.00","totalWordCount":4}
# "acquires"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":5}
# "across"	{"averageDiff":"-317.64","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"92.03","averageLow":"-464.10","averageVolume":"18293436241.20","totalWordCount":25}
# "act"	{"averageDiff":"-310.68","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"162.70","averageLow":"-516.99","averageVolume":"20606642088.25","totalWordCount":14}
# "action"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":53}
# "actions"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "active"	{"averageDiff":"-441.36","maxDiff":"-38.58","minDiff":"-1113.95","averageHigh":"130.42","averageLow":"-673.65","averageVolume":"23036522206.67","totalWordCount":13}
# "activities"	{"averageDiff":"387.06","maxDiff":"387.06","minDiff":"387.06","averageHigh":"480.22","averageLow":"-89.93","averageVolume":"16644534842.00","totalWordCount":3}
# "activity"	{"averageDiff":"-167.61","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"232.64","averageLow":"-449.44","averageVolume":"20987684146.60","totalWordCount":21}
# "actual"	{"averageDiff":"21.39","maxDiff":"81.37","minDiff":"-38.58","averageHigh":"277.99","averageLow":"-201.28","averageVolume":"17988882613.50","totalWordCount":8}
# "actually"	{"averageDiff":"-233.40","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"129.16","averageLow":"-397.37","averageVolume":"18783019656.43","totalWordCount":58}
# "ada"	{"averageDiff":"-109.10","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"224.32","averageLow":"-342.81","averageVolume":"19372659337.29","totalWordCount":70}
# "adam"	{"averageDiff":"-182.10","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"198.31","averageLow":"-397.14","averageVolume":"19355003734.33","totalWordCount":24}
# "adapad"	{"averageDiff":"-374.48","maxDiff":"-374.48","minDiff":"-374.48","averageHigh":"63.55","averageLow":"-444.19","averageVolume":"20535363434.00","totalWordCount":3}
# "add"	{"averageDiff":"-1.53","maxDiff":"495.62","minDiff":"-374.48","averageHigh":"288.27","averageLow":"-262.21","averageVolume":"20312473675.40","totalWordCount":22}
# "added"	{"averageDiff":"-1.53","maxDiff":"495.62","minDiff":"-374.48","averageHigh":"288.27","averageLow":"-262.21","averageVolume":"20312473675.40","totalWordCount":20}
# "address"	{"averageDiff":"-125.81","maxDiff":"81.37","minDiff":"-374.48","averageHigh":"177.91","averageLow":"-312.19","averageVolume":"19224881794.25","totalWordCount":20}
# "addresses"	{"averageDiff":"-143.62","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"225.26","averageLow":"-387.73","averageVolume":"19118931794.40","totalWordCount":25}
# "adds"	{"averageDiff":"-234.79","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"186.07","averageLow":"-467.16","averageVolume":"20562604134.60","totalWordCount":17}
# "adidas"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":6}
# "administration"	{"averageDiff":"-45.09","maxDiff":"81.37","minDiff":"-171.55","averageHigh":"175.83","averageLow":"-224.50","averageVolume":"16851700124.50","totalWordCount":6}
# "adopt"	{"averageDiff":"-401.38","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"118.12","averageLow":"-570.80","averageVolume":"19921934953.00","totalWordCount":12}
# "adopted"	{"averageDiff":"-34.58","maxDiff":"81.37","minDiff":"-171.55","averageHigh":"172.59","averageLow":"-242.13","averageVolume":"16882544164.00","totalWordCount":15}
# "adopting"	{"averageDiff":"189.14","maxDiff":"495.62","minDiff":"-9.57","averageHigh":"343.83","averageLow":"-91.08","averageVolume":"16381951948.67","totalWordCount":15}
# "adoption"	{"averageDiff":"-83.46","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"234.89","averageLow":"-325.98","averageVolume":"19198723737.44","totalWordCount":130}
# "adults"	{"averageDiff":"-273.02","maxDiff":"-171.55","minDiff":"-374.48","averageHigh":"77.84","averageLow":"-423.10","averageVolume":"20460880975.00","totalWordCount":7}
# "advance"	{"averageDiff":"35.90","maxDiff":"81.37","minDiff":"-9.57","averageHigh":"150.90","averageLow":"-105.47","averageVolume":"12241507323.00","totalWordCount":7}
# "advanced"	{"averageDiff":"-516.29","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"131.12","averageLow":"-655.20","averageVolume":"19689703171.50","totalWordCount":9}
# "advantage"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":3}
# "advantages"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":4}
# "adventure"	{"averageDiff":"-263.29","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"274.84","averageLow":"-575.90","averageVolume":"23703881442.00","totalWordCount":13}
# "advertising"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":3}
# "advice"	{"averageDiff":"-19.71","maxDiff":"495.62","minDiff":"-374.48","averageHigh":"244.81","averageLow":"-285.60","averageVolume":"19882275911.40","totalWordCount":25}
# "adviser"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "advisory"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "ae"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":3}
# "af"	{"averageDiff":"-516.29","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"131.12","averageLow":"-655.20","averageVolume":"19689703171.50","totalWordCount":8}
# "affect"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
# "afford"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "africa"	{"averageDiff":"-333.42","maxDiff":"-9.57","minDiff":"-1113.95","averageHigh":"108.38","averageLow":"-546.23","averageVolume":"20068894883.25","totalWordCount":25}
# "african"	{"averageDiff":"-347.39","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"101.50","averageLow":"-491.44","averageVolume":"16848473085.33","totalWordCount":11}
# "ag"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "age"	{"averageDiff":"-268.14","maxDiff":"-7.06","minDiff":"-1113.95","averageHigh":"116.20","averageLow":"-458.08","averageVolume":"19525754485.60","totalWordCount":17}
# "agency"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
# "agenda"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "agentorangebtc"	{"averageDiff":"-7.06","maxDiff":"-7.06","minDiff":"-7.06","averageHigh":"147.48","averageLow":"-105.50","averageVolume":"17353192895.00","totalWordCount":3}
# "aggregator"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":4}
# "agix"	{"averageDiff":"-90.56","maxDiff":"-9.57","minDiff":"-171.55","averageHigh":"67.19","averageLow":"-282.97","averageVolume":"15776205714.50","totalWordCount":13}
# "ago"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":90}
# "agree"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":57}
# "agreed"	{"averageDiff":"132.84","maxDiff":"495.62","minDiff":"-38.58","averageHigh":"358.29","averageLow":"-142.59","averageVolume":"19498449830.50","totalWordCount":16}
# "ah"	{"averageDiff":"-263.29","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"274.84","averageLow":"-575.90","averageVolume":"23703881442.00","totalWordCount":12}
# "ahcastor"	{"averageDiff":"-642.75","maxDiff":"-171.55","minDiff":"-1113.95","averageHigh":"47.41","averageLow":"-832.70","averageVolume":"23224401563.00","totalWordCount":20}
# "ahead"	{"averageDiff":"-161.59","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"212.33","averageLow":"-391.20","averageVolume":"19827255128.57","totalWordCount":66}
# "ai"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":300}
# "aidistrict"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":5}
# "aims"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":3}
# "aion"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":3}
# "air"	{"averageDiff":"-118.56","maxDiff":"81.37","minDiff":"-374.48","averageHigh":"114.37","averageLow":"-264.28","averageVolume":"16351194149.00","totalWordCount":17}
# "airdrop"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":75}
# "airdropcrypto"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":8}
# "airdrops"	{"averageDiff":"95.16","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"372.75","averageLow":"-273.29","averageVolume":"22570001070.00","totalWordCount":16}
# "airdropstario"	{"averageDiff":"-642.75","maxDiff":"-171.55","minDiff":"-1113.95","averageHigh":"47.41","averageLow":"-832.70","averageVolume":"23224401563.00","totalWordCount":12}
# "airport"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "aj"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":4}
# "aka"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "akro"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":3}
# "al"	{"averageDiff":"-177.13","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"271.02","averageLow":"-443.67","averageVolume":"21107161514.75","totalWordCount":16}
# "alchemy"	{"averageDiff":"-374.48","maxDiff":"-374.48","minDiff":"-374.48","averageHigh":"63.55","averageLow":"-444.19","averageVolume":"20535363434.00","totalWordCount":5}
# "alert"	{"averageDiff":"-271.13","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"126.10","averageLow":"-446.02","averageVolume":"19021324116.67","totalWordCount":25}
# "alerts"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":4}
# "alex"	{"averageDiff":"-199.86","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"216.70","averageLow":"-472.91","averageVolume":"20569414309.75","totalWordCount":12}
# "alexanderthebtc"	{"averageDiff":"-273.02","maxDiff":"-171.55","minDiff":"-374.48","averageHigh":"77.84","averageLow":"-423.10","averageVolume":"20460880975.00","totalWordCount":21}
# "alexmicmac"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":3}
# "alexstanczyk"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":5}
# "algo"	{"averageDiff":"-62.73","maxDiff":"-7.06","minDiff":"-171.55","averageHigh":"93.95","averageLow":"-223.81","averageVolume":"16301868108.00","totalWordCount":13}
# "algorand"	{"averageDiff":"-263.29","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"274.84","averageLow":"-575.90","averageVolume":"23703881442.00","totalWordCount":12}
# "ali"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":3}
# "alice"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "alive"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "allamerican"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "alleged"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
# "allow"	{"averageDiff":"-126.11","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"237.13","averageLow":"-382.37","averageVolume":"19709237077.67","totalWordCount":33}
# "allowing"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "allows"	{"averageDiff":"-34.58","maxDiff":"81.37","minDiff":"-171.55","averageHigh":"172.59","averageLow":"-242.13","averageVolume":"16882544164.00","totalWordCount":20}
# "allure"	{"averageDiff":"-374.48","maxDiff":"-374.48","minDiff":"-374.48","averageHigh":"63.55","averageLow":"-444.19","averageVolume":"20535363434.00","totalWordCount":4}
# "allverse"	{"averageDiff":"-244.15","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"108.82","averageLow":"-396.37","averageVolume":"17657002133.40","totalWordCount":23}
# "almost"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":52}
# "alone"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":4}
# "along"	{"averageDiff":"98.97","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"280.90","averageLow":"-168.81","averageVolume":"17383063590.50","totalWordCount":15}
# "alph"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "alpha"	{"averageDiff":"-333.42","maxDiff":"-9.57","minDiff":"-1113.95","averageHigh":"108.38","averageLow":"-546.23","averageVolume":"20068894883.25","totalWordCount":17}
# "alphr"	{"averageDiff":"-7.06","maxDiff":"-7.06","minDiff":"-7.06","averageHigh":"147.48","averageLow":"-105.50","averageVolume":"17353192895.00","totalWordCount":3}
# "already"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":110}
# "also"	{"averageDiff":"-83.46","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"234.89","averageLow":"-325.98","averageVolume":"19198723737.44","totalWordCount":161}
# "alt"	{"averageDiff":"-42.92","maxDiff":"81.37","minDiff":"-171.55","averageHigh":"216.03","averageLow":"-268.19","averageVolume":"18788054581.00","totalWordCount":12}
# "altcoin"	{"averageDiff":"-83.46","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"234.89","averageLow":"-325.98","averageVolume":"19198723737.44","totalWordCount":738}
# "altcoindailyio"	{"averageDiff":"-207.12","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"280.24","averageLow":"-520.82","averageVolume":"23443101955.00","totalWordCount":26}
# "altcoins"	{"averageDiff":"-83.46","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"234.89","averageLow":"-325.98","averageVolume":"19198723737.44","totalWordCount":194}
# "altcoinseason"	{"averageDiff":"228.52","maxDiff":"495.62","minDiff":"-38.58","averageHigh":"513.07","averageLow":"-208.94","averageVolume":"23661802347.00","totalWordCount":6}
# "alternative"	{"averageDiff":"-143.11","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"246.31","averageLow":"-376.04","averageVolume":"20356367790.80","totalWordCount":25}
# "altgemsalert"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "although"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "alts"	{"averageDiff":"71.46","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"284.01","averageLow":"-206.16","averageVolume":"18438603571.20","totalWordCount":52}
# "altseason"	{"averageDiff":"-73.24","maxDiff":"-9.57","minDiff":"-171.55","averageHigh":"143.60","averageLow":"-307.17","averageVolume":"18071058307.67","totalWordCount":12}
# "alveychain"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":20}
# "always"	{"averageDiff":"-83.46","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"234.89","averageLow":"-325.98","averageVolume":"19198723737.44","totalWordCount":199}
# "amazing"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":175}
# "amazon"	{"averageDiff":"-240.59","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"236.90","averageLow":"-505.49","averageVolume":"22861554250.80","totalWordCount":31}
# "amb"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "ambitious"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":6}
# "amc"	{"averageDiff":"-234.79","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"186.07","averageLow":"-467.16","averageVolume":"20562604134.60","totalWordCount":57}
# "amendment"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "america"	{"averageDiff":"-157.09","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"191.05","averageLow":"-355.47","averageVolume":"19069030757.29","totalWordCount":59}
# "american"	{"averageDiff":"-15.00","maxDiff":"495.62","minDiff":"-374.48","averageHigh":"231.91","averageLow":"-268.11","averageVolume":"19187654015.75","totalWordCount":26}
# "americanos"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "americans"	{"averageDiff":"-110.72","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"236.34","averageLow":"-328.43","averageVolume":"18512290670.20","totalWordCount":26}
# "amid"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":67}
# "amidst"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "among"	{"averageDiff":"95.16","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"372.75","averageLow":"-273.29","averageVolume":"22570001070.00","totalWordCount":21}
# "amount"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":90}
# "amp"	{"averageDiff":"-83.46","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"234.89","averageLow":"-325.98","averageVolume":"19198723737.44","totalWordCount":608}
# "amplify"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "amritaahuja"	{"averageDiff":"-374.48","maxDiff":"-374.48","minDiff":"-374.48","averageHigh":"63.55","averageLow":"-444.19","averageVolume":"20535363434.00","totalWordCount":3}
# "amzdoge"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "amzn"	{"averageDiff":"-199.86","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"216.70","averageLow":"-472.91","averageVolume":"20569414309.75","totalWordCount":41}
# "analizcikurt"	{"averageDiff":"-7.06","maxDiff":"-7.06","minDiff":"-7.06","averageHigh":"147.48","averageLow":"-105.50","averageVolume":"17353192895.00","totalWordCount":6}
# "analysis"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":118}
# "analyst"	{"averageDiff":"-167.61","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"232.64","averageLow":"-449.44","averageVolume":"20987684146.60","totalWordCount":18}
# "analysts"	{"averageDiff":"162.03","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"410.91","averageLow":"-232.15","averageVolume":"22524619858.00","totalWordCount":7}
# "analytics"	{"averageDiff":"-1.53","maxDiff":"495.62","minDiff":"-374.48","averageHigh":"288.27","averageLow":"-262.21","averageVolume":"20312473675.40","totalWordCount":24}
# "andrew"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "animalfarmdefi"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":7}
# "announced"	{"averageDiff":"-341.63","maxDiff":"-9.57","minDiff":"-1113.95","averageHigh":"99.41","averageLow":"-525.82","averageVolume":"20162188593.40","totalWordCount":21}
# "announcement"	{"averageDiff":"228.52","maxDiff":"495.62","minDiff":"-38.58","averageHigh":"513.07","averageLow":"-208.94","averageVolume":"23661802347.00","totalWordCount":7}
# "announces"	{"averageDiff":"-417.39","maxDiff":"-9.57","minDiff":"-1113.95","averageHigh":"50.16","averageLow":"-568.38","averageVolume":"19537544868.25","totalWordCount":26}
# "annual"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":6}
# "anon"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":6}
# "anonymous"	{"averageDiff":"91.71","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"344.45","averageLow":"-216.72","averageVolume":"20256751235.75","totalWordCount":46}
# "another"	{"averageDiff":"-83.46","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"234.89","averageLow":"-325.98","averageVolume":"19198723737.44","totalWordCount":155}
# "answer"	{"averageDiff":"-109.10","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"224.32","averageLow":"-342.81","averageVolume":"19372659337.29","totalWordCount":32}
# "answers"	{"averageDiff":"288.50","maxDiff":"495.62","minDiff":"81.37","averageHigh":"494.62","averageLow":"-54.65","averageVolume":"18989921466.50","totalWordCount":7}
# "anti"	{"averageDiff":"-347.39","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"101.50","averageLow":"-491.44","averageVolume":"16848473085.33","totalWordCount":11}
# "antifud"	{"averageDiff":"-93.01","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"245.82","averageLow":"-353.54","averageVolume":"19429415092.75","totalWordCount":264}
# "anupamaa"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "anymore"	{"averageDiff":"-117.02","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"266.13","averageLow":"-378.44","averageVolume":"19573804790.00","totalWordCount":19}
# "anyone"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":85}
# "anything"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":60}
# "anytime"	{"averageDiff":"-309.17","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"366.21","averageLow":"-662.85","averageVolume":"25362622905.00","totalWordCount":6}
# "ape"	{"averageDiff":"-263.29","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"274.84","averageLow":"-575.90","averageVolume":"23703881442.00","totalWordCount":27}
# "apes"	{"averageDiff":"27.52","maxDiff":"495.62","minDiff":"-374.48","averageHigh":"363.23","averageLow":"-287.35","averageVolume":"22619656042.67","totalWordCount":16}
# "apk"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "apompliano"	{"averageDiff":"60.57","maxDiff":"495.62","minDiff":"-374.48","averageHigh":"396.62","averageLow":"-253.25","averageVolume":"22599102317.00","totalWordCount":12}
# "app"	{"averageDiff":"-161.59","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"212.33","averageLow":"-391.20","averageVolume":"19827255128.57","totalWordCount":71}
# "apparel"	{"averageDiff":"-105.07","maxDiff":"-38.58","minDiff":"-171.55","averageHigh":"194.28","averageLow":"-378.78","averageVolume":"21523581005.00","totalWordCount":9}
# "appetite"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":5}
# "apple"	{"averageDiff":"4.28","maxDiff":"495.62","minDiff":"-374.48","averageHigh":"237.43","averageLow":"-223.89","averageVolume":"18013523559.20","totalWordCount":21}
# "application"	{"averageDiff":"-206.53","maxDiff":"-38.58","minDiff":"-374.48","averageHigh":"180.00","averageLow":"-399.88","averageVolume":"21598063464.00","totalWordCount":30}
# "applications"	{"averageDiff":"135.15","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"360.45","averageLow":"-170.43","averageVolume":"19455413816.33","totalWordCount":16}
# "applied"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":3}
# "apply"	{"averageDiff":"162.03","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"410.91","averageLow":"-232.15","averageVolume":"22524619858.00","totalWordCount":6}
# "appreciate"	{"averageDiff":"-387.37","maxDiff":"-9.57","minDiff":"-1113.95","averageHigh":"113.80","averageLow":"-594.30","averageVolume":"19963060339.00","totalWordCount":9}
# "approach"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":4}
# "approval"	{"averageDiff":"21.39","maxDiff":"81.37","minDiff":"-38.58","averageHigh":"277.99","averageLow":"-201.28","averageVolume":"17988882613.50","totalWordCount":11}
# "approve"	{"averageDiff":"-576.27","maxDiff":"-38.58","minDiff":"-1113.95","averageHigh":"149.57","averageLow":"-809.48","averageVolume":"24361584052.00","totalWordCount":7}
# "approved"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
# "approving"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":3}
# "approximately"	{"averageDiff":"135.15","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"360.45","averageLow":"-170.43","averageVolume":"19455413816.33","totalWordCount":12}
# "apps"	{"averageDiff":"-263.29","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"274.84","averageLow":"-575.90","averageVolume":"23703881442.00","totalWordCount":13}
# "april"	{"averageDiff":"-209.89","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"140.09","averageLow":"-389.57","averageVolume":"18490962360.17","totalWordCount":28}
# "apt"	{"averageDiff":"-73.24","maxDiff":"-9.57","minDiff":"-171.55","averageHigh":"143.60","averageLow":"-307.17","averageVolume":"18071058307.67","totalWordCount":10}
# "aptos"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":5}
# "ar"	{"averageDiff":"-105.07","maxDiff":"-38.58","minDiff":"-171.55","averageHigh":"194.28","averageLow":"-378.78","averageVolume":"21523581005.00","totalWordCount":7}
# "arbitrum"	{"averageDiff":"-216.60","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"229.52","averageLow":"-443.78","averageVolume":"20992801898.60","totalWordCount":29}
# "architects"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "archive"	{"averageDiff":"-161.59","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"212.33","averageLow":"-391.20","averageVolume":"19827255128.57","totalWordCount":74}
# "area"	{"averageDiff":"-323.44","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"142.87","averageLow":"-502.43","averageVolume":"20592386357.40","totalWordCount":21}
# "areas"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":3}
# "argon"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "argue"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":5}
# "ariaswave"	{"averageDiff":"-206.53","maxDiff":"-38.58","minDiff":"-374.48","averageHigh":"180.00","averageLow":"-399.88","averageVolume":"21598063464.00","totalWordCount":9}
# "ark"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":3}
# "armstrong"	{"averageDiff":"-303.43","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"99.16","averageLow":"-469.08","averageVolume":"17732954443.00","totalWordCount":27}
# "army"	{"averageDiff":"-206.53","maxDiff":"-38.58","minDiff":"-374.48","averageHigh":"180.00","averageLow":"-399.88","averageVolume":"21598063464.00","totalWordCount":6}
# "arnc"	{"averageDiff":"162.03","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"410.91","averageLow":"-232.15","averageVolume":"22524619858.00","totalWordCount":7}
# "aroha"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "around"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":259}
# "arsbou"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "art"	{"averageDiff":"-161.59","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"212.33","averageLow":"-391.20","averageVolume":"19827255128.57","totalWordCount":129}
# "artcollectors"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":5}
# "arthur"	{"averageDiff":"-45.09","maxDiff":"81.37","minDiff":"-171.55","averageHigh":"175.83","averageLow":"-224.50","averageVolume":"16851700124.50","totalWordCount":9}
# "article"	{"averageDiff":"-2.87","maxDiff":"495.62","minDiff":"-374.48","averageHigh":"247.27","averageLow":"-245.83","averageVolume":"18788063548.33","totalWordCount":29}
# "artificial"	{"averageDiff":"-126.11","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"237.13","averageLow":"-382.37","averageVolume":"19709237077.67","totalWordCount":29}
# "artist"	{"averageDiff":"-105.07","maxDiff":"-38.58","minDiff":"-171.55","averageHigh":"194.28","averageLow":"-378.78","averageVolume":"21523581005.00","totalWordCount":11}
# "artistontwitter"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "artordai"	{"averageDiff":"-347.39","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"101.50","averageLow":"-491.44","averageVolume":"16848473085.33","totalWordCount":14}
# "artsymonke"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "ascending"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
# "ashcryptoreal"	{"averageDiff":"-73.24","maxDiff":"-9.57","minDiff":"-171.55","averageHigh":"143.60","averageLow":"-307.17","averageVolume":"18071058307.67","totalWordCount":11}
# "asia"	{"averageDiff":"-303.43","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"99.16","averageLow":"-469.08","averageVolume":"17732954443.00","totalWordCount":31}
# "asian"	{"averageDiff":"-642.75","maxDiff":"-171.55","minDiff":"-1113.95","averageHigh":"47.41","averageLow":"-832.70","averageVolume":"23224401563.00","totalWordCount":8}
# "ask"	{"averageDiff":"-126.11","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"237.13","averageLow":"-382.37","averageVolume":"19709237077.67","totalWordCount":40}
# "asked"	{"averageDiff":"60.57","maxDiff":"495.62","minDiff":"-374.48","averageHigh":"396.62","averageLow":"-253.25","averageVolume":"22599102317.00","totalWordCount":6}
# "asking"	{"averageDiff":"71.46","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"284.01","averageLow":"-206.16","averageVolume":"18438603571.20","totalWordCount":18}
# "aspects"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "asset"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":123}
# "assets"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":98}
# "associated"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "assure"	{"averageDiff":"-374.48","maxDiff":"-374.48","minDiff":"-374.48","averageHigh":"63.55","averageLow":"-444.19","averageVolume":"20535363434.00","totalWordCount":3}
# "asw"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
# "ath"	{"averageDiff":"-161.59","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"212.33","averageLow":"-391.20","averageVolume":"19827255128.57","totalWordCount":64}
# "atm"	{"averageDiff":"-333.42","maxDiff":"-9.57","minDiff":"-1113.95","averageHigh":"108.38","averageLow":"-546.23","averageVolume":"20068894883.25","totalWordCount":23}
# "atms"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":8}
# "atolo"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "atom"	{"averageDiff":"-90.56","maxDiff":"-9.57","minDiff":"-171.55","averageHigh":"67.19","averageLow":"-282.97","averageVolume":"15776205714.50","totalWordCount":15}
# "atomicmojo"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "attack"	{"averageDiff":"-207.12","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"280.24","averageLow":"-520.82","averageVolume":"23443101955.00","totalWordCount":23}
# "attackontitan"	{"averageDiff":"35.90","maxDiff":"81.37","minDiff":"-9.57","averageHigh":"150.90","averageLow":"-105.47","averageVolume":"12241507323.00","totalWordCount":66}
# "attempts"	{"averageDiff":"-642.75","maxDiff":"-171.55","minDiff":"-1113.95","averageHigh":"47.41","averageLow":"-832.70","averageVolume":"23224401563.00","totalWordCount":9}
# "attending"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":4}
# "attention"	{"averageDiff":"-186.93","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"240.68","averageLow":"-429.07","averageVolume":"21270795497.83","totalWordCount":29}
# "attracted"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "attractive"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "auction"	{"averageDiff":"244.28","maxDiff":"495.62","minDiff":"-7.06","averageHigh":"438.59","averageLow":"-83.90","averageVolume":"21008017047.50","totalWordCount":10}
# "audited"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "ault"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "aurora"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":6}
# "australia"	{"averageDiff":"-202.09","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.46","averageLow":"-448.56","averageVolume":"20912297361.17","totalWordCount":28}
# "ausvind"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "authentic"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "author"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "authorized"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "auto"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "automated"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":3}
# "autonomous"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":3}
# "autonomy"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":4}
# "available"	{"averageDiff":"-143.11","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"246.31","averageLow":"-376.04","averageVolume":"20356367790.80","totalWordCount":24}
# "avalanche"	{"averageDiff":"-303.43","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"99.16","averageLow":"-469.08","averageVolume":"17732954443.00","totalWordCount":27}
# "avax"	{"averageDiff":"-161.59","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"212.33","averageLow":"-391.20","averageVolume":"19827255128.57","totalWordCount":47}
# "average"	{"averageDiff":"-161.59","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"212.33","averageLow":"-391.20","averageVolume":"19827255128.57","totalWordCount":35}
# "aversion"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":4}
# "aviv"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":6}
# "avoid"	{"averageDiff":"69.61","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"316.44","averageLow":"-231.34","averageVolume":"21265799026.25","totalWordCount":18}
# "aw"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":4}
# "aware"	{"averageDiff":"-32.41","maxDiff":"81.37","minDiff":"-171.55","averageHigh":"166.38","averageLow":"-184.83","averageVolume":"17018864381.33","totalWordCount":14}
# "awareness"	{"averageDiff":"-7.06","maxDiff":"-7.06","minDiff":"-7.06","averageHigh":"147.48","averageLow":"-105.50","averageVolume":"17353192895.00","totalWordCount":4}
# ...
# "xentagz"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":3}
# "xf"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
# "xgem"	{"averageDiff":"91.71","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"344.45","averageLow":"-216.72","averageVolume":"20256751235.75","totalWordCount":25}
# "xi"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "xiaomi"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":3}
# "xilena"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "xircus"	{"averageDiff":"-303.43","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"99.16","averageLow":"-469.08","averageVolume":"17732954443.00","totalWordCount":25}
# "xircusweb"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":6}
# "xj"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "xlm"	{"averageDiff":"-90.56","maxDiff":"-9.57","minDiff":"-171.55","averageHigh":"67.19","averageLow":"-282.97","averageVolume":"15776205714.50","totalWordCount":8}
# "xm"	{"averageDiff":"37.19","maxDiff":"495.62","minDiff":"-374.48","averageHigh":"278.50","averageLow":"-223.48","averageVolume":"18788072515.67","totalWordCount":9}
# "xmaximist"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "xmon"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "xmr"	{"averageDiff":"-430.85","maxDiff":"-7.06","minDiff":"-1113.95","averageHigh":"80.77","averageLow":"-590.30","averageVolume":"21267332007.00","totalWordCount":16}
# "xnft"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "xp"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":4}
# "xpla"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "xportal"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
# "xrp"	{"averageDiff":"-83.46","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"234.89","averageLow":"-325.98","averageVolume":"19198723737.44","totalWordCount":282}
# "xu"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "xv"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "xverseapp"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":4}
# "xz"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "xzo"	{"averageDiff":"179.47","maxDiff":"495.62","minDiff":"-38.58","averageHigh":"428.56","averageLow":"-154.96","averageVolume":"20213535475.67","totalWordCount":19}
# "ya"	{"averageDiff":"-33.25","maxDiff":"81.37","minDiff":"-171.55","averageHigh":"131.30","averageLow":"-204.31","averageVolume":"14956471054.00","totalWordCount":9}
# "yacht"	{"averageDiff":"-374.48","maxDiff":"-374.48","minDiff":"-374.48","averageHigh":"63.55","averageLow":"-444.19","averageVolume":"20535363434.00","totalWordCount":3}
# "yangang"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":8}
# "yb"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":5}
# "ydf"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "ye"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
# "yeah"	{"averageDiff":"-83.46","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"234.89","averageLow":"-325.98","averageVolume":"19198723737.44","totalWordCount":42}
# "year"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":252}
# "years"	{"averageDiff":"-83.46","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"234.89","averageLow":"-325.98","averageVolume":"19198723737.44","totalWordCount":251}
# "yellen"	{"averageDiff":"387.06","maxDiff":"387.06","minDiff":"387.06","averageHigh":"480.22","averageLow":"-89.93","averageVolume":"16644534842.00","totalWordCount":3}
# "yellow"	{"averageDiff":"-469.02","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"108.60","averageLow":"-584.86","averageVolume":"19971589925.67","totalWordCount":9}
# "yep"	{"averageDiff":"-374.48","maxDiff":"-374.48","minDiff":"-374.48","averageHigh":"63.55","averageLow":"-444.19","averageVolume":"20535363434.00","totalWordCount":3}
# "yes"	{"averageDiff":"-83.46","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"234.89","averageLow":"-325.98","averageVolume":"19198723737.44","totalWordCount":95}
# "yesterday"	{"averageDiff":"-126.11","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"237.13","averageLow":"-382.37","averageVolume":"19709237077.67","totalWordCount":41}
# "yet"	{"averageDiff":"-83.46","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"234.89","averageLow":"-325.98","averageVolume":"19198723737.44","totalWordCount":129}
# "yeti"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":4}
# "yettocome"	{"averageDiff":"-561.76","maxDiff":"-9.57","minDiff":"-1113.95","averageHigh":"22.48","averageLow":"-713.67","averageVolume":"18614208761.50","totalWordCount":6}
# "yevolution"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "yfi"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":4}
# "ygg"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":4}
# "yield"	{"averageDiff":"-441.36","maxDiff":"-38.58","minDiff":"-1113.95","averageHigh":"130.42","averageLow":"-673.65","averageVolume":"23036522206.67","totalWordCount":20}
# "yieldfarming"	{"averageDiff":"-45.09","maxDiff":"81.37","minDiff":"-171.55","averageHigh":"175.83","averageLow":"-224.50","averageVolume":"16851700124.50","totalWordCount":18}
# "yieldvault"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "yj"	{"averageDiff":"21.39","maxDiff":"81.37","minDiff":"-38.58","averageHigh":"277.99","averageLow":"-201.28","averageVolume":"17988882613.50","totalWordCount":6}
# "yk"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "ylaq"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":3}
# "ym"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "ynofvdx"	{"averageDiff":"-22.25","maxDiff":"495.62","minDiff":"-374.48","averageHigh":"295.45","averageLow":"-316.01","averageVolume":"22061341661.00","totalWordCount":22}
# "yo"	{"averageDiff":"-24.08","maxDiff":"-9.57","minDiff":"-38.58","averageHigh":"169.34","averageLow":"-259.75","averageVolume":"16913388203.50","totalWordCount":12}
# "york"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":3}
# "young"	{"averageDiff":"-561.76","maxDiff":"-9.57","minDiff":"-1113.95","averageHigh":"22.48","averageLow":"-713.67","averageVolume":"18614208761.50","totalWordCount":6}
# "youpars"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":4}
# "yourcryptodj"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":5}
# "youth"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "youtube"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":78}
# "yp"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "yq"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":3}
# "yr"	{"averageDiff":"-374.48","maxDiff":"-374.48","minDiff":"-374.48","averageHigh":"63.55","averageLow":"-444.19","averageVolume":"20535363434.00","totalWordCount":4}
# "yt"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "yuan"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":5}
# "yuga"	{"averageDiff":"-263.29","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"274.84","averageLow":"-575.90","averageVolume":"23703881442.00","totalWordCount":31}
# "yugalabs"	{"averageDiff":"-16.81","maxDiff":"495.62","minDiff":"-374.48","averageHigh":"295.12","averageLow":"-302.83","averageVolume":"21861534383.33","totalWordCount":27}
# "yupa"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":563}
# "yw"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "yx"	{"averageDiff":"135.15","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"360.45","averageLow":"-170.43","averageVolume":"19455413816.33","totalWordCount":9}
# "z"	{"averageDiff":"-142.28","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"204.22","averageLow":"-355.49","averageVolume":"19517997349.38","totalWordCount":231}
# "za"	{"averageDiff":"162.03","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"410.91","averageLow":"-232.15","averageVolume":"22524619858.00","totalWordCount":8}
# "zap"	{"averageDiff":"162.03","maxDiff":"495.62","minDiff":"-171.55","averageHigh":"410.91","averageLow":"-232.15","averageVolume":"22524619858.00","totalWordCount":6}
# "zc"	{"averageDiff":"-146.56","maxDiff":"81.37","minDiff":"-374.48","averageHigh":"161.55","averageLow":"-245.59","averageVolume":"16926182583.50","totalWordCount":7}
# "zcash"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "zd"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "zec"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "zelensky"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":3}
# "zenadrone"	{"averageDiff":"-431.69","maxDiff":"-9.57","minDiff":"-1113.95","averageHigh":"45.69","averageLow":"-609.78","averageVolume":"19204938679.67","totalWordCount":13}
# "zero"	{"averageDiff":"-161.59","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"212.33","averageLow":"-391.20","averageVolume":"19827255128.57","totalWordCount":50}
# "zerohedge"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":4}
# "zesty"	{"averageDiff":"-38.58","maxDiff":"-38.58","minDiff":"-38.58","averageHigh":"296.44","averageLow":"-355.57","averageVolume":"22660763494.00","totalWordCount":9}
# "zf"	{"averageDiff":"-26.70","maxDiff":"81.37","minDiff":"-171.55","averageHigh":"135.35","averageLow":"-179.61","averageVolume":"15555651514.25","totalWordCount":125}
# "zg"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
# "zil"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
# "zimbabwean"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":3}
# "zk"	{"averageDiff":"-303.43","maxDiff":"81.37","minDiff":"-1113.95","averageHigh":"99.16","averageLow":"-469.08","averageVolume":"17732954443.00","totalWordCount":16}
# "zkevm"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
# "zone"	{"averageDiff":"-83.46","maxDiff":"495.62","minDiff":"-1113.95","averageHigh":"234.89","averageLow":"-325.98","averageVolume":"19198723737.44","totalWordCount":165}
# "zoo"	{"averageDiff":"-1113.95","maxDiff":"-1113.95","minDiff":"-1113.95","averageHigh":"2.71","averageLow":"-1263.39","averageVolume":"26062404610.00","totalWordCount":3}
# "zoom"	{"averageDiff":"-90.56","maxDiff":"-9.57","minDiff":"-171.55","averageHigh":"67.19","averageLow":"-282.97","averageVolume":"15776205714.50","totalWordCount":6}
# "zq"	{"averageDiff":"495.62","maxDiff":"495.62","minDiff":"495.62","averageHigh":"729.70","averageLow":"-62.30","averageVolume":"24662841200.00","totalWordCount":3}
# "zrx"	{"averageDiff":"-171.55","maxDiff":"-171.55","minDiff":"-171.55","averageHigh":"92.12","averageLow":"-402.00","averageVolume":"20386398516.00","totalWordCount":6}
# "zurich"	{"averageDiff":"81.37","maxDiff":"81.37","minDiff":"81.37","averageHigh":"259.54","averageLow":"-47.00","averageVolume":"13317001733.00","totalWordCount":4}
# "zx"	{"averageDiff":"-9.57","maxDiff":"-9.57","minDiff":"-9.57","averageHigh":"42.25","averageLow":"-163.94","averageVolume":"11166012913.00","totalWordCount":3}
